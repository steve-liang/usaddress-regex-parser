# %%
# !ls
# Out:
# CaseInsensitiveDict.py __init__.py            parser.py
# Untitled.ipynb         __pycache__            suffix.csv

# %%
import pandas as pd
import re
from CaseInsensitiveDict import CaseInsensitiveDict
from parser import parse_building_address
line = "-Unit #203-B,  300-499,   North State STREET @chicago, ste 3210b"

# %%
suffix_csv = pd.read_csv('/Users/steve/Documents/Github/addressR/suffix.csv')

# %%
suffix_dict = suffix_csv.set_index('input')['output'].to_dict()

# %%
def replace_it(m):
    return suffix_i.get(m.group('key'), m.group(0))

# %%
suffix_i = CaseInsensitiveDict(suffix_dict)

# %%
re.sub(r'(?i)(?P<key>[a-zA-Z]+)', replace_it, line)
# Out:
# '-Unit #203-B,  300-499,   North State St @chicago, ste 3210b'

# %%
dat = pd.read_csv('/Users/steve/Downloads/us-500.csv')
dat.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1        phone2  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email                                  web
# 0                jbutt@gmail.com         http://www.bentonjohnbjr.com
# ...

# %%
dat['STD_ADDRESS'] = dat['address'].apply(lambda x: parse_building_address(x))

# %%
dat[['address','STD_ADDRESS']]
# Out:
#                      address             STD_ADDRESS
# 0         6649 N Blue Gum St      6649 N Blue Gum St
# 1        4 B Blue Ridge Blvd       4 B Blue Rdg Blvd
# 2       8 W Cerritos Ave #54        8 W Cerritos Ave
# 3                639 Main St             639 Main St
# 4               34 Center St               34 Ctr St
# 5               3 Mcauley Dr            3 Mcauley Dr
# 6                  7 Eads St               7 Eads St
# 7           7 W Jackson Blvd        7 W Jackson Blvd
# 8           5 Boston Ave #88            5 Boston Ave
# 9      228 Runamuck Pl #2808         228 Runamuck Pl
# 10          2371 Jerrold Ave        2371 Jerrold Ave
# 11        37275 St  Rt 17m M       37275 St Rt 17m M
# 12          25 E 75th St #69            25 E 75th St
# 13     98 Connecticut Ave Nw   98 Connecticut Ave NW
# 14          56 E Morehead St        56 E Morehead St
# 15       73 State Road 434 E       73 State Rd 434 E
# 16       69734 E Carrillo St     69734 E Carrillo St
# ...
